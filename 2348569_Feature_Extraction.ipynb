# %% [markdown]
# <a href="https://colab.research.google.com/github/Tdas-christ/CV/blob/main/2348569_Feature_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage import exposure
from skimage import feature

# %% [markdown]
# # **Loading the Images**

# %%
img1 = cv2.imread('/content/drive/MyDrive/IMAGES (CV)/hill_scenery.jpg', cv2.IMREAD_GRAYSCALE)

img2 = cv2.imread('/content/drive/MyDrive/IMAGES (CV)/house.jpg', cv2.IMREAD_GRAYSCALE)

img3 = cv2.imread('/content/drive/MyDrive/IMAGES (CV)/river.jpg', cv2.IMREAD_GRAYSCALE)

img4 = cv2.imread('/content/drive/MyDrive/IMAGES (CV)/statue.jpg', cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# # **Printing the original images as grayscale images**

# %%
plt.figure(figsize=(14,12))

plt.subplot(2, 2, 1)
plt.title("Image 1")
plt.imshow(img1, cmap='gray')
plt.axis("off")

plt.subplot(2, 2, 2)
plt.title("Image 2")
plt.imshow(img2, cmap='gray')
plt.axis("off")

plt.subplot(2, 2, 3)
plt.title("Image 3")
plt.imshow(img3, cmap='gray')
plt.axis("off")

plt.subplot(2, 2, 4)
plt.title("Image 4")
plt.imshow(img4, cmap='gray')
plt.axis("off")

plt.show()

# %% [markdown]
# # **Point Extraction**

# %%
point_mask = np.array([[1, 1, 1],
                       [1, -8, 1],
                       [1, 1, 1]])
img_point1 = cv2.filter2D(img1, -1, point_mask)
img_point2 = cv2.filter2D(img2, -1, point_mask)
img_point3 = cv2.filter2D(img3, -1, point_mask)
img_point4 = cv2.filter2D(img4, -1, point_mask)

# %%
plt.figure(figsize=(14,12))

plt.subplot(2, 2, 1)
plt.title("Points in Image 1")
plt.imshow(img_point1, cmap='gray')
plt.axis("off")

plt.subplot(2, 2, 2)
plt.title("Points in Image 2")
plt.imshow(img_point2, cmap='gray')
plt.axis("off")

plt.subplot(2, 2, 3)
plt.title("Points in Image 3")
plt.imshow(img_point3, cmap='gray')
plt.axis("off")

plt.subplot(2, 2, 4)
plt.title("Points in Image 4")
plt.imshow(img_point4, cmap='gray')
plt.axis("off")

plt.show()

# %% [markdown]
# # **Line Extraction**

# %%
vertical_mask = np.array([[-1, 2, -1],
                          [-1, 2, -1],
                          [-1, 2, -1]])
horizontal_mask = np.array([[-1, -1, -1],
                            [2, 2, 2],
                            [-1, -1, -1]])

plus_45_mask = np.array([[-1, -1, 2],
                         [-1, 2, -1],
                         [2, -1, -1]])

minus_45_mask = np.array([[2, -1, -1],
                          [-1, 2, -1],
                          [-1, -1, 2]])

# %% [markdown]
# # Convolution with the mask

# %%
#image1
vertical_lines = cv2.filter2D(img1, -1, vertical_mask)
horizontal_lines = cv2.filter2D(img1, -1, horizontal_mask)
plus_45_lines = cv2.filter2D(img1, -1, plus_45_mask)
minus_45_lines = cv2.filter2D(img1, -1, minus_45_mask)

# %%
#image 2
vertical_lines2 = cv2.filter2D(img2, -1, vertical_mask)
horizontal_lines2 = cv2.filter2D(img2, -1, horizontal_mask)
plus_45_lines2 = cv2.filter2D(img2, -1, plus_45_mask)
minus_45_lines2 = cv2.filter2D(img2, -1, minus_45_mask)

# %%
#image 3
vertical_lines3 = cv2.filter2D(img3, -1, vertical_mask)
horizontal_lines3 = cv2.filter2D(img3, -1, horizontal_mask)
plus_45_lines3 = cv2.filter2D(img3, -1, plus_45_mask)
minus_45_lines3 = cv2.filter2D(img3, -1, minus_45_mask)

# %%
#image 4
vertical_lines4 = cv2.filter2D(img4, -1, vertical_mask)
horizontal_lines4 = cv2.filter2D(img4, -1, horizontal_mask)
plus_45_lines4 = cv2.filter2D(img4, -1, plus_45_mask)
minus_45_lines4 = cv2.filter2D(img4, -1, minus_45_mask)

# %% [markdown]
# # Plotting the outputs

# %%
plt.figure(figsize=(14,12))

plt.subplot(1,4,1)
plt.title("Horizontal Lines in Image 1")
plt.imshow(horizontal_lines,cmap='gray')
plt.axis("off")

plt.subplot(1,4,2)
plt.title("Vertical Lines in Image 1")
plt.imshow(vertical_lines,cmap='gray')
plt.axis("off")

plt.subplot(1,4,3)
plt.title("+45 Lines in Image 1")
plt.imshow(plus_45_lines,cmap='gray')
plt.axis("off")

plt.subplot(1,4,4)
plt.title("-45 Lines in Image 1")
plt.imshow(minus_45_lines,cmap='gray')
plt.axis("off")

plt.show()

# %%
plt.figure(figsize=(14,12))

plt.subplot(1,4,1)
plt.title("Horizontal Lines in Image 2")
plt.imshow(horizontal_lines2,cmap='gray')
plt.axis("off")

plt.subplot(1,4,2)
plt.title("Vertical Lines in Image 2")
plt.imshow(vertical_lines2,cmap='gray')
plt.axis("off")

plt.subplot(1,4,3)
plt.title("+45 Lines in Image 2")
plt.imshow(plus_45_lines2,cmap='gray')
plt.axis("off")

plt.subplot(1,4,4)
plt.title("-45 Lines in Image 2")
plt.imshow(minus_45_lines2,cmap='gray')
plt.axis("off")

plt.show()

# %%
plt.figure(figsize=(14,12))

plt.subplot(1,4,1)
plt.title("Horizontal Lines in Image 3")
plt.imshow(horizontal_lines3,cmap='gray')
plt.axis("off")

plt.subplot(1,4,2)
plt.title("Vertical Lines in Image 3")
plt.imshow(vertical_lines3,cmap='gray')
plt.axis("off")

plt.subplot(1,4,3)
plt.title("+45 Lines in Image 3")
plt.imshow(plus_45_lines3,cmap='gray')
plt.axis("off")

plt.subplot(1,4,4)
plt.title("-45 Lines in Image 3")
plt.imshow(minus_45_lines3,cmap='gray')
plt.axis("off")

plt.show()

# %%
plt.figure(figsize=(14,12))

plt.subplot(1,4,1)
plt.title("Horizontal Lines in Image 4")
plt.imshow(horizontal_lines4,cmap='gray')
plt.axis("off")

plt.subplot(1,4,2)
plt.title("Vertical Lines in Image 4")
plt.imshow(vertical_lines4,cmap='gray')
plt.axis("off")

plt.subplot(1,4,3)
plt.title("+45 Lines in Image 4")
plt.imshow(plus_45_lines4,cmap='gray')
plt.axis("off")

plt.subplot(1,4,4)
plt.title("-45 Lines in Image 4")
plt.imshow(minus_45_lines4,cmap='gray')
plt.axis("off")

plt.show()

# %% [markdown]
# # **Edge Extraction**

# %%
def detect_edges(image):
    edges = cv2.Canny(image, 100, 200)
    return edges

# %%
edges_image1 = detect_edges(img1)
edges_image2 = detect_edges(img2)
edges_image3 = detect_edges(img3)
edges_image4 = detect_edges(img4)

# %%
plt.figure(figsize=(14,12))

plt.subplot(1,4,1)
plt.title("Edges in Image 1")
plt.imshow(edges_image1,cmap='gray')
plt.axis("off")

plt.subplot(1,4,2)
plt.title("Edges in Image 2")
plt.imshow(edges_image2,cmap='gray')
plt.axis("off")

plt.subplot(1,4,3)
plt.title("Edges in Image 3")
plt.imshow(edges_image3,cmap='gray')
plt.axis("off")

plt.subplot(1,4,4)
plt.title("Edges in Image 4")
plt.imshow(edges_image4,cmap='gray')
plt.axis("off")

plt.show()
